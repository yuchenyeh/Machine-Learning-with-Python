# %% [markdown]
# # Line chart

# %%
import matplotlib.pyplot as plt

df = pd.DataFrame(
   {
      "Car": ['BMW', 'Lexus', 'Audi', 'Mustang', 'Bentley', 'Jaguar'],"Reg_Price": [2000, 2500, 2800, 3000, 3200, 3500],"Units": [100, 120, 150, 170, 180, 200]
   }
)
plt.plot(df["Reg_Price"], df["Units"], color='red')
plt.xlabel('Reg_Price')
plt.ylabel('Units')
#plt.xlim()
#plt.ylim()
#plt.xticks()
plt.show()

# %% [markdown]
# # bar chart

# %%
plt.bar(df["Car"], df["Units"])
# Out:
# <BarContainer object of 6 artists>

# %%
plt.barh(df["Car"], df["Units"])
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# # scatter

# %%
plt.scatter(df["Reg_Price"], df["Units"])

# %% [markdown]
# # pandas

# %%
df["Units"].plot(kind="area")
# Out:
# <Axes: >

# %%
df["Units"].plot(kind="line")
# Out:
# <Axes: >

# %%
df.plot(kind="scatter", x="Reg_Price", y="Units")
# Out:
# <Axes: xlabel='Reg_Price', ylabel='Units'>

# %%
df["Units"].plot(kind="barh")
# Out:
# <Axes: >

# %%
df["Units"].plot(kind="pie")
# Out:
# <Axes: ylabel='Units'>

# %%
df["Units"].plot(kind="bar")
# Out:
# <Axes: >

# %%
df.plot(kind="hist", x="Reg_Price",  bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Reg_Price"].plot(kind="box")
# Out:
# <Axes: >

# %%
df["Reg_Price"].plot(kind="kde",bw_method=0.3)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # seaborn

# %%
import seaborn as sns

sns.lineplot(data=df, x="Reg_Price", y="Units")
# Out:
# <Axes: xlabel='Reg_Price', ylabel='Units'>

# %%
sns.barplot(data=df, x="Car", y="Units")
# Out:
# <Axes: xlabel='Car', ylabel='Units'>

# %%
sns.scatterplot(data=df, x="Reg_Price", y="Units")
# Out:
# <Axes: xlabel='Reg_Price', ylabel='Units'>

# %% [markdown]
# # plotly

# %%
import plotly.express as px
px.line(df, x="Reg_Price", y="Units")

# %%
px.scatter(df, x="Reg_Price", y="Units")

# %%
px.bar(df, x="Car", y="Units")
